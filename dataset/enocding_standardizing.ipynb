# %% [markdown]
# ## Encoding Categorical Columns

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/agg_df.csv')

# %%
# Drop accident_number column, don't need this anymore
# Dropped department because granularity is too fine.
# If treated as a categorical column, this would result in too many columns.
# It is also redundant with the region column.

df.drop(['accident_number', 'department'], axis = 1, inplace = True)

# %%
# Get cateogrical columns
cat_cols = df.select_dtypes(include=["object"]).drop(columns=["date"]).columns.tolist()
cat_cols
# Out:
# ['day_of_week',
#  'road_category',
#  'road_layout',
#  'reserved_lane',
#  'road_profile',
#  'road_shape',
#  'surface_condition',
#  'infrastructure',
#  'road_location',
#  'light_conditions',
#  'urban_area',
#  'intersection_type',
#  'weather',
#  'collision_type',
#  'region']

# %%
df_encoded = pd.get_dummies(df, columns=cat_cols, drop_first=True)

# %%
# Get numerical columns and drop the target column
# Remove hour column as this needs cyclical encoding
num_cols = df.select_dtypes(include=["number"]).drop(columns=["injury_severity", "hour"]).columns.tolist()
num_cols
# Out:
# ['num_lanes', 'speed_limit', 'users_involved', 'latitude', 'longitude']

# %%
# Scale num cols
scaler = StandardScaler()
scaled_features = scaler.fit_transform(df[num_cols])
scaled_df = pd.DataFrame(scaled_features, columns=[f"{col}_scaled" for col in num_cols], index=df.index)

# Concatenate with original DataFrame
df_encoded = pd.concat([df_encoded, scaled_df], axis=1)

# %%
# Inserting to front of df
df_encoded.insert(5, "num_lanes_scaled", df_encoded.pop("num_lanes_scaled"))
df_encoded.insert(6, "speed_limit_scaled", df_encoded.pop("speed_limit_scaled"))
df_encoded.insert(7, "users_involved_scaled", df_encoded.pop("users_involved_scaled"))
df_encoded.insert(8, "latitude_scaled", df_encoded.pop("latitude_scaled"))
df_encoded.insert(9, "longitude_scaled", df_encoded.pop("longitude_scaled"))

# %%
# Cyclical encoding for hour
df_encoded["hour_sin"] = np.sin(2 * np.pi * df_encoded["hour"]/24)
df_encoded["hour_cos"] = np.cos(2 * np.pi * df_encoded["hour"]/24)

# Inserting to front of df
df_encoded.insert(2, "hour_sin", df_encoded.pop("hour_sin"))
df_encoded.insert(3, "hour_cos", df_encoded.pop("hour_cos"))

# %%
# Remove original columns
df_encoded.drop(columns=['num_lanes', 'speed_limit', 'users_involved'], inplace=True)

# %%
# Inserting to front of df
df_encoded.insert(2, "latitude", df_encoded.pop("latitude"))
df_encoded.insert(3, "longitude", df_encoded.pop("longitude"))
df_encoded.insert(4, "injury_severity", df_encoded.pop("injury_severity"))

# %%
df_encoded.head()
# Out:
#          date  hour   latitude  longitude  injury_severity  hour_sin  \
# 0  2019-11-30     1  48.896210   2.470120                4  0.258819
# 1  2019-11-30     2  48.930700   2.368800                4  0.500000
# 2  2019-11-28    15  48.935872   2.319174                4 -0.707107
# 3  2019-11-30    20  48.817329   2.428150                4 -0.866025
# 4  2019-11-30     4  48.776362   2.433254                4  0.866025
#
#    hour_cos  num_lanes_scaled  speed_limit_scaled  users_involved_scaled  \
# 0  0.965926          5.875965            0.449901               0.618866
# 1  0.866025         -0.368344            0.449901              -1.047900
# 2 -0.707107          4.314888            1.366414               1.452249
# 3  0.500000          1.973272            1.366414               1.452249
# 4  0.500000          0.412195            1.366414               0.618866
#
#    latitude_scaled  longitude_scaled  day_of_week_Monday  \
# 0         0.802672         -0.046186               False
# 1         0.818374         -0.087279               False
# 2         0.820729         -0.107405               False
# 3         0.766759         -0.063208               False
# 4         0.748108         -0.061138               False
#
#    day_of_week_Saturday  day_of_week_Sunday  day_of_week_Thursday  \
# 0                  True               False                 False
# 1                  True               False                 False
# 2                 False               False                  True
# 3                  True               False                 False
# 4                  True               False                 False
#
#    day_of_week_Tuesday  day_of_week_Wednesday  road_category_Major Roads  \
# 0                False                  False                       True
# 1                False                  False                       True
# 2                False                  False                       True
# 3                False                  False                       True
# 4                False                  False                       True
#
#    road_category_Other / Off-Network  road_category_Secondary Roads  \
# 0                              False                          False
# 1                              False                          False
# 2                              False                          False
# 3                              False                          False
# 4                              False                          False
#
#    road_layout_One Way  road_layout_Two Way  reserved_lane_No value  \
# 0                False                False                    True
# 1                 True                False                    True
# 2                False                False                    True
# 3                False                False                    True
# 4                 True                False                    True
#
#    reserved_lane_Reserved Lane  road_profile_Slope / Near Slope  \
# 0                        False                            False
# 1                        False                             True
# 2                        False                            False
# 3                        False                            False
# 4                        False                            False
#
#    road_shape_Straight  surface_condition_Wet / Slippery  \
# 0                False                             False
# 1                False                             False
# 2                False                             False
# 3                 True                             False
# 4                False                             False
#
#    infrastructure_No value  infrastructure_Other  \
# 0                    False                 False
# 1                     True                 False
# 2                     True                 False
# 3                     True                 False
# 4                    False                 False
#
#    infrastructure_Tunnel / Bridge  road_location_Other  \
# 0                            True                False
# 1                           False                False
# 2                           False                False
# 3                           False                False
# 4                            True                False
#
#    road_location_Reserved Lanes  road_location_Road  light_conditions_Night  \
# 0                         False                True                    True
# 1                         False                True                    True
# 2                         False                True                   False
# 3                         False                True                    True
# 4                         False                True                    True
#
#    light_conditions_Twilight  urban_area_Outside urban area  \
# 0                      False                           True
# 1                      False                           True
# 2                      False                           True
# 3                      False                           True
# 4                      False                           True
#
#    intersection_type_No junction  intersection_type_Other junction  \
# 0                           True                             False
# 1                           True                             False
# 2                           True                             False
# 3                           True                             False
# 4                           True                             False
#
#    intersection_type_Simple junction  weather_Reduced Traction  \
# 0                              False                     False
# 1                              False                     False
# 2                              False                     False
# 3                              False                     False
# 4                              False                     False
#
#    weather_Reduced Visibility  collision_type_Multi-car collision  \
# 0                       False                               False
# 1                       False                                True
# 2                       False                                True
# 3                       False                                True
# 4                       False                               False
#
#    collision_type_No collision  region_Bourgogne-Franche-Comté  \
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                           False
# 4                        False                           False
#
#    region_Bretagne  region_Centre-Val de Loire  region_Grand Est  \
# 0            False                       False             False
# 1            False                       False             False
# 2            False                       False             False
# 3            False                       False             False
# 4            False                       False             False
#
#    region_Hauts-de-France  region_Normandie  region_Nouvelle-Aquitaine  \
# 0                   False             False                      False
# 1                   False             False                      False
# 2                   False             False                      False
# 3                   False             False                      False
# 4                   False             False                      False
#
#    region_Occitanie  region_Pays de la Loire  \
# 0             False                    False
# 1             False                    False
# 2             False                    False
# 3             False                    False
# 4             False                    False
#
#    region_Provence-Alpes-Côte d’Azur  region_Île-de-France
# 0                              False                  True
# 1                              False                  True
# 2                              False                  True
# 3                              False                  True
# 4                              False                  True

# %%
df_encoded.shape
# Out:
# (204145, 55)

# %%
df_encoded.to_csv('../data/encoded_df.csv', index=False)
