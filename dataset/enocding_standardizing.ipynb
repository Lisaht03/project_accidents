# %% [markdown]
# ## Encoding Categorical Columns

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/agg_df.csv')

# %%
df.head()
# Out:
#    accident_number        date day_of_week  hour road_category road_layout  \
# 0     201900000001  2019-11-30    Saturday     1   Major Roads  Multi Lane
# 1     201900000002  2019-11-30    Saturday     2   Major Roads     One Way
# 2     201900000003  2019-11-28    Thursday    15   Major Roads  Multi Lane
# 3     201900000004  2019-11-30    Saturday    20   Major Roads  Multi Lane
# 4     201900000005  2019-11-30    Saturday     4   Major Roads     One Way
#
#    num_lanes reserved_lane        road_profile road_shape surface_condition  \
# 0         10      No value                Flat     Curved            Normal
# 1          2      No value  Slope / Near Slope     Curved            Normal
# 2          8      No value                Flat     Curved            Normal
# 3          5      No value                Flat   Straight            Normal
# 4          3      No value                Flat     Curved            Normal
#
#     infrastructure road_location  speed_limit  injury_severity  \
# 0  Tunnel / Bridge          Road           70                4
# 1         No value          Road           70                4
# 2         No value          Road           90                4
# 3         No value          Road           90                4
# 4  Tunnel / Bridge          Road           90                4
#
#    users_involved light_conditions         department          urban_area  \
# 0               3            Night  Seine-Saint-Denis  Outside urban area
# 1               1            Night  Seine-Saint-Denis  Outside urban area
# 2               4              Day     Hauts-de-Seine  Outside urban area
# 3               4            Night       Val-de-Marne  Outside urban area
# 4               3            Night       Val-de-Marne  Outside urban area
#
#   intersection_type            weather       collision_type   latitude  \
# 0       No junction  Normal Visibility      2-car collision  48.896210
# 1       No junction  Normal Visibility  Multi-car collision  48.930700
# 2       No junction  Normal Visibility  Multi-car collision  48.935872
# 3       No junction  Normal Visibility  Multi-car collision  48.817329
# 4       No junction  Normal Visibility      2-car collision  48.776362
#
#    longitude
# 0   2.470120
# 1   2.368800
# 2   2.319174
# 3   2.428150
# 4   2.433254

# %%
# Drop accident_number column, don't need this anymore

df.drop(['accident_number'], axis = 1, inplace = True)

# %%
# Get cateogrical columns
cat_cols = df.select_dtypes(include=["object"]).drop(columns=["date"]).columns.tolist()
cat_cols
# Out:
# ['day_of_week',
#  'road_category',
#  'road_layout',
#  'reserved_lane',
#  'road_profile',
#  'road_shape',
#  'surface_condition',
#  'infrastructure',
#  'road_location',
#  'light_conditions',
#  'department',
#  'urban_area',
#  'intersection_type',
#  'weather',
#  'collision_type']

# %%
df_encoded = pd.get_dummies(df, columns=cat_cols, drop_first=True)

# %%
# Get numerical columns and drop the target column
# Remove hour column as this needs cyclical encoding
num_cols = df.select_dtypes(include=["number"]).drop(columns=["injury_severity", "hour"]).columns.tolist()
num_cols
# Out:
# ['num_lanes', 'speed_limit', 'users_involved', 'latitude', 'longitude']

# %%
# Scale num cols
scaler = StandardScaler()
scaled_features = scaler.fit_transform(df[num_cols])
scaled_df = pd.DataFrame(scaled_features, columns=[f"{col}_scaled" for col in num_cols], index=df.index)

# Concatenate with original DataFrame
df_encoded = pd.concat([df_encoded, scaled_df], axis=1)

# %%
# Inserting to front of df
df_encoded.insert(5, "num_lanes_scaled", df_encoded.pop("num_lanes_scaled"))
df_encoded.insert(6, "speed_limit_scaled", df_encoded.pop("speed_limit_scaled"))
df_encoded.insert(7, "users_involved_scaled", df_encoded.pop("users_involved_scaled"))
df_encoded.insert(8, "latitude_scaled", df_encoded.pop("latitude_scaled"))
df_encoded.insert(9, "longitude_scaled", df_encoded.pop("longitude_scaled"))

# %%
# Cyclical encoding for hour
df_encoded["hour_sin"] = np.sin(2 * np.pi * df_encoded["hour"]/24)
df_encoded["hour_cos"] = np.cos(2 * np.pi * df_encoded["hour"]/24)

# Inserting to front of df
df_encoded.insert(2, "hour_sin", df_encoded.pop("hour_sin"))
df_encoded.insert(3, "hour_cos", df_encoded.pop("hour_cos"))

# %%
# Remove original columns
df_encoded.drop(columns=['num_lanes', 'speed_limit', 'users_involved'], inplace=True)

# %%
# Inserting to front of df
df_encoded.insert(2, "latitude", df_encoded.pop("latitude"))
df_encoded.insert(3, "longitude", df_encoded.pop("longitude"))
df_encoded.insert(4, "injury_severity", df_encoded.pop("injury_severity"))

# %%
df_encoded.head()
# Out:
#          date  hour   latitude  longitude  injury_severity  hour_sin  \
# 0  2019-11-30     1  48.896210   2.470120                4  0.258819
# 1  2019-11-30     2  48.930700   2.368800                4  0.500000
# 2  2019-11-28    15  48.935872   2.319174                4 -0.707107
# 3  2019-11-30    20  48.817329   2.428150                4 -0.866025
# 4  2019-11-30     4  48.776362   2.433254                4  0.866025
#
#    hour_cos  num_lanes_scaled  speed_limit_scaled  users_involved_scaled  \
# 0  0.965926          4.220637            0.614804               0.721277
# 1  0.866025         -0.513104            0.614804              -1.179960
# 2 -0.707107          3.037202            1.523458               1.671896
# 3  0.500000          1.262049            1.523458               1.671896
# 4  0.500000          0.078613            1.523458               0.721277
#
#    latitude_scaled  longitude_scaled  day_of_week_Monday  \
# 0         0.286293          0.648763               False
# 1         0.476901          0.020106               False
# 2         0.505483         -0.287804               False
# 3        -0.149640          0.388354               False
# 4        -0.376046          0.420021               False
#
#    day_of_week_Saturday  day_of_week_Sunday  day_of_week_Thursday  \
# 0                  True               False                 False
# 1                  True               False                 False
# 2                 False               False                  True
# 3                  True               False                 False
# 4                  True               False                 False
#
#    day_of_week_Tuesday  day_of_week_Wednesday  road_category_Major Roads  \
# 0                False                  False                       True
# 1                False                  False                       True
# 2                False                  False                       True
# 3                False                  False                       True
# 4                False                  False                       True
#
#    road_category_Other / Off-Network  road_category_Secondary Roads  \
# 0                              False                          False
# 1                              False                          False
# 2                              False                          False
# 3                              False                          False
# 4                              False                          False
#
#    road_layout_One Way  road_layout_Two Way  reserved_lane_No value  \
# 0                False                False                    True
# 1                 True                False                    True
# 2                False                False                    True
# 3                False                False                    True
# 4                 True                False                    True
#
#    reserved_lane_Reserved Lane  road_profile_Slope / Near Slope  \
# 0                        False                            False
# 1                        False                             True
# 2                        False                            False
# 3                        False                            False
# 4                        False                            False
#
#    road_shape_Straight  surface_condition_Wet / Slippery  \
# 0                False                             False
# 1                False                             False
# 2                False                             False
# 3                 True                             False
# 4                False                             False
#
#    infrastructure_No value  infrastructure_Other  \
# 0                    False                 False
# 1                     True                 False
# 2                     True                 False
# 3                     True                 False
# 4                    False                 False
#
#    infrastructure_Tunnel / Bridge  road_location_Other  \
# 0                            True                False
# 1                           False                False
# 2                           False                False
# 3                           False                False
# 4                            True                False
#
#    road_location_Reserved Lanes  road_location_Road  light_conditions_Night  \
# 0                         False                True                    True
# 1                         False                True                    True
# 2                         False                True                   False
# 3                         False                True                    True
# 4                         False                True                    True
#
#    light_conditions_Twilight  department_Hauts-de-Seine  department_Paris  \
# 0                      False                      False             False
# 1                      False                      False             False
# 2                      False                       True             False
# 3                      False                      False             False
# 4                      False                      False             False
#
#    department_Seine-Saint-Denis  department_Seine-et-Marne  \
# 0                          True                      False
# 1                          True                      False
# 2                         False                      False
# 3                         False                      False
# 4                         False                      False
#
#    department_Val-d'Oise  department_Val-de-Marne  department_Yvelines  \
# 0                  False                    False                False
# 1                  False                    False                False
# 2                  False                    False                False
# 3                  False                     True                False
# 4                  False                     True                False
#
#    urban_area_Outside urban area  intersection_type_No junction  \
# 0                           True                           True
# 1                           True                           True
# 2                           True                           True
# 3                           True                           True
# 4                           True                           True
#
#    intersection_type_Other junction  intersection_type_Simple junction  \
# 0                             False                              False
# 1                             False                              False
# 2                             False                              False
# 3                             False                              False
# 4                             False                              False
#
#    weather_Reduced Traction  weather_Reduced Visibility  \
# 0                     False                       False
# 1                     False                       False
# 2                     False                       False
# 3                     False                       False
# 4                     False                       False
#
#    collision_type_Multi-car collision  collision_type_No collision
# 0                               False                        False
# 1                                True                        False
# 2                                True                        False
# 3                                True                        False
# 4                               False                        False

# %%
df_encoded.shape
# Out:
# (65093, 51)

# %%
df_encoded.to_csv('../data/encoded_df.csv', index=False)
